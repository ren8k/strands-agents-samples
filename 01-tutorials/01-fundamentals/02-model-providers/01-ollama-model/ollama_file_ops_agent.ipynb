# %% [markdown]
# # Building a Local Agent with Strands Agents and Ollama Model
#
# This notebook demonstrates how to create a personal agent using Strands Agent and Ollama. The agent will be capable of performing various local tasks such as file operations, web searches, and system commands.
#
# ## What is Ollama?
#
# [Ollama](https://ollama.com/) is an open-source framework that allows you to run large language models (LLMs) locally on your machine. It provides a simple API for interacting with these models, making it ideal for privacy-focused applications where you don't want to send data to external services.
#
# Key benefits of Ollama:
#
# - **Privacy**: All processing happens locally on your machine
# - **No API costs**: Free to use as much as you want
# - **Offline capability**: Works without internet connection
# - **Customization**: Can be fine-tuned for specific use
#
# ## Agent Details
#
# <div style="float: left; margin-right: 20px;">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Feature used        |Ollama Model - to create a file operations agent   |
# |Agent Structure     |Single agent architecture                          |
#
# </div>

# %% [markdown]
# ### Agent Architecture
#
# <div style="text-align:center">
#     <img src="images/architecture.png" width="65%" />
# </div>

# %%
# !pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -ackaging (/opt/conda/envs/pytorch/lib/python3.10/site-packages)
# Requirement already satisfied: strands-agents in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: strands-agents-tools in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.34.148)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.34.154)
# Requirement already satisfied: docstring-parser<0.16.0,>=0.15 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.15)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.30.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.2.1)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.0.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Collecting ollama<1.0.0,>=0.4.8 (from strands-agents[ollama]->-r requirements.txt (line 3))
#   Downloading ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests>=0.14.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.10.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: httpx>=0.27 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2.3.6)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.47.0)
# Requirement already satisfied: uvicorn>=0.23.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.34.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (6.8.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: opentelemetry-proto==1.34.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opentelemetry-proto==1.34.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opentelemetry-sdk<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (0.55b0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.9)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.16.1)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.35.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: certifi in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: click>=7.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from uvicorn>=0.23.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (8.2.1)
# Downloading ollama-0.5.1-py3-none-any.whl (13 kB)
# WARNING: Ignoring invalid distribution -ackaging (/opt/conda/envs/pytorch/lib/python3.10/site-packages)
# Installing collected packages: ollama
# Successfully installed ollama-0.5.1

# %% [markdown]
# ## Setup and Installation
#
# Before running this notebook, make sure you have:
#
# 1. Install Ollama: Follow instructions at [https://ollama.com/download](https://ollama.com/download)
# 2. Start the Ollama server: `ollama serve`
# 3. Downloaded a model with Ollama: `ollama pull llama3.2:1b`
#
# Refer to the [documentation](https://cuddly-sniffle-lrmk2y7.pages.github.io/0.1.x/user-guide/concepts/model-providers/ollama/) for detailed instructions.
#
# In this notebook, we will download Ollama for the linux distribution for compatibility with SageMaker Studio. This is done for code execution during AWS lead workshops on Workshop Studio. If you are running this code locally, you should adjust the steps to download Ollama to your current enviroment.

# %%
# this will work on linux computers
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# curl: /opt/conda/envs/pytorch/lib/libcurl.so.4: no version information available (required by curl)
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# curl: /opt/conda/envs/pytorch/lib/libcurl.so.4: no version information available (required by curl)
# ######################################################################## 100.0%   76.4%
# >>> Creating ollama user...
# >>> Adding ollama user to render group...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> Enabling and starting ollama service...
# Created symlink /etc/systemd/system/default.target.wants/ollama.service → /etc/systemd/system/ollama.service.
# >>> NVIDIA GPU installed.

# %%
import subprocess

subprocess.Popen(["ollama", "serve"])
# Out:
# <Popen: returncode: None args: ['ollama', 'serve']>

# %%
# !ollama pull llama3.2:1b
# Out:
# Couldn't find '/home/ubuntu/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIEVnha8tirpcBHcCQjXUf17dbiV3b4+3WpQPWCoDeNRY
# Error: listen tcp 127.0.0.1:11434: bind: address already in use
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling 74701a8c35f6:   0% ▕                  ▏ 1.5 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   3% ▕                  ▏  33 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   4% ▕                  ▏  51 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   6% ▕█                 ▏  85 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:   8% ▕█                 ▏ 103 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:  11% ▕█                 ▏ 139 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:  13% ▕██                ▏ 172 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:  15% ▕██                ▏ 197 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:  16% ▕██                ▏ 216 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:  19% ▕███               ▏ 250 MB/1.3 GB                  pulling manifest
# pulling 74701a8c35f6:  22% ▕███               ▏ 288 MB/1.3 GB  287 MB/s      3spulling manifest
# pulling 74701a8c35f6:  23% ▕████              ▏ 301 MB/1.3 GB  287 MB/s      3spulling manifest
# pulling 74701a8c35f6:  25% ▕████              ▏ 332 MB/1.3 GB  287 MB/s      3spulling manifest
# pulling 74701a8c35f6:  28% ▕█████             ▏ 375 MB/1.3 GB  287 MB/s      3spulling manifest
# pulling 74701a8c35f6:  30% ▕█████             ▏ 389 MB/1.3 GB  287 MB/s      3spulling manifest
# pulling 74701a8c35f6:  33% ▕█████             ▏ 432 MB/1.3 GB  287 MB/s      3spulling manifest
# pulling 74701a8c35f6:  35% ▕██████            ▏ 462 MB/1.3 GB  287 MB/s      2spulling manifest
# pulling 74701a8c35f6:  37% ▕██████            ▏ 484 MB/1.3 GB  287 MB/s      2spulling manifest
# pulling 74701a8c35f6:  39% ▕███████           ▏ 518 MB/1.3 GB  287 MB/s      2spulling manifest
# pulling 74701a8c35f6:  40% ▕███████           ▏ 534 MB/1.3 GB  287 MB/s      2spulling manifest
# pulling 74701a8c35f6:  43% ▕███████           ▏ 568 MB/1.3 GB  287 MB/s      2spulling manifest
# pulling 74701a8c35f6:  46% ▕████████          ▏ 608 MB/1.3 GB  290 MB/s      2spulling manifest
# pulling 74701a8c35f6:  49% ▕████████          ▏ 642 MB/1.3 GB  290 MB/s      2spulling manifest
# pulling 74701a8c35f6:  50% ▕████████          ▏ 657 MB/1.3 GB  290 MB/s      2spulling manifest
# pulling 74701a8c35f6:  52% ▕█████████         ▏ 689 MB/1.3 GB  290 MB/s      2spulling manifest
# pulling 74701a8c35f6:  54% ▕█████████         ▏ 709 MB/1.3 GB  290 MB/s      2spulling manifest
# pulling 74701a8c35f6:  56% ▕██████████        ▏ 737 MB/1.3 GB  290 MB/s      2spulling manifest
# pulling 74701a8c35f6:  58% ▕██████████        ▏ 766 MB/1.3 GB  290 MB/s      1spulling manifest
# pulling 74701a8c35f6:  60% ▕██████████        ▏ 796 MB/1.3 GB  290 MB/s      1spulling manifest
# pulling 74701a8c35f6:  62% ▕███████████       ▏ 817 MB/1.3 GB  290 MB/s      1spulling manifest
# pulling 74701a8c35f6:  65% ▕███████████       ▏ 861 MB/1.3 GB  290 MB/s      1spulling manifest
# pulling 74701a8c35f6:  67% ▕███████████       ▏ 880 MB/1.3 GB  292 MB/s      1spulling manifest
# pulling 74701a8c35f6:  69% ▕████████████      ▏ 911 MB/1.3 GB  292 MB/s      1spulling manifest
# pulling 74701a8c35f6:  73% ▕█████████████     ▏ 959 MB/1.3 GB  292 MB/s      1spulling manifest
# pulling 74701a8c35f6:  75% ▕█████████████     ▏ 990 MB/1.3 GB  292 MB/s      1spulling manifest
# pulling 74701a8c35f6:  76% ▕█████████████     ▏ 1.0 GB/1.3 GB  292 MB/s      1spulling manifest
# pulling 74701a8c35f6:  78% ▕██████████████    ▏ 1.0 GB/1.3 GB  292 MB/s      0spulling manifest
# pulling 74701a8c35f6:  81% ▕██████████████    ▏ 1.1 GB/1.3 GB  292 MB/s      0spulling manifest
# pulling 74701a8c35f6:  82% ▕██████████████    ▏ 1.1 GB/1.3 GB  292 MB/s      0spulling manifest
# pulling 74701a8c35f6:  85% ▕███████████████   ▏ 1.1 GB/1.3 GB  292 MB/s      0spulling manifest
# pulling 74701a8c35f6:  87% ▕███████████████   ▏ 1.1 GB/1.3 GB  292 MB/s      0spulling manifest
# pulling 74701a8c35f6:  90% ▕████████████████  ▏ 1.2 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  93% ▕████████████████  ▏ 1.2 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  95% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  96% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  97% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  295 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  98% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  258 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6:  99% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0spulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B                         pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 74701a8c35f6: 100% ▕█████████████████ ▏ 1.3 GB/1.3 GB  218 MB/s      0s
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 4f659a1e86d7: 100% ▕██████████████████▏  485 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Import necessary libraries
import os

import requests

# Import strands components
from strands import Agent, tool
from strands.models.ollama import OllamaModel

# %%
# Check if Ollama is running:
try:
    response = requests.get("http://localhost:11434/api/tags")
    print("✅ Ollama is running. Available models:")
    for model in response.json().get("models", []):
        print(f"- {model['name']}")
except requests.exceptions.ConnectionError:
    print("❌ Ollama is not running. Please start Ollama before proceeding.")
# Out:
# ✅ Ollama is running. Available models:
# - llama3.2:1b

# %% [markdown]
# ## Defining Custom Tools
#
# Tools are functions that the agent can use to interact with the environment. Below, we define several useful tools for our personal agent.

# %%
# File Operation Tools


@tool
def file_read(file_path: str) -> str:
    """Read a file and return its content.

    Args:
        file_path (str): Path to the file to read

    Returns:
        str: Content of the file

    Raises:
        FileNotFoundError: If the file doesn't exist
    """
    try:
        with open(file_path, "r") as file:
            return file.read()
    except FileNotFoundError:
        return f"Error: File '{file_path}' not found."
    except Exception as e:
        return f"Error reading file: {str(e)}"


@tool
def file_write(file_path: str, content: str) -> str:
    """Write content to a file.

    Args:
        file_path (str): The path to the file
        content (str): The content to write to the file

    Returns:
        str: A message indicating success or failure
    """
    try:
        # Create directory if it doesn't exist
        os.makedirs(os.path.dirname(os.path.abspath(file_path)), exist_ok=True)

        with open(file_path, "w") as file:
            file.write(content)
        return f"File '{file_path}' written successfully."
    except Exception as e:
        return f"Error writing to file: {str(e)}"


@tool
def list_directory(directory_path: str = ".") -> str:
    """List files and directories in the specified path.

    Args:
        directory_path (str): Path to the directory to list

    Returns:
        str: A formatted string listing all files and directories
    """
    try:
        items = os.listdir(directory_path)
        files = []
        directories = []

        for item in items:
            full_path = os.path.join(directory_path, item)
            if os.path.isdir(full_path):
                directories.append(f"Folder: {item}/")
            else:
                files.append(f"File: {item}")

        result = f"Contents of {os.path.abspath(directory_path)}:\n"
        result += (
            "\nDirectories:\n" + "\n".join(sorted(directories))
            if directories
            else "\nNo directories found."
        )
        result += (
            "\n\nFiles:\n" + "\n".join(sorted(files)) if files else "\nNo files found."
        )

        return result
    except Exception as e:
        return f"Error listing directory: {str(e)}"

# %% [markdown]
# ## Creating the Ollama-powered Agent
#
# Now we'll create our agent using the Ollama model and the tools we defined above.
#
# Note: You can add more tools like `execute_commands`, `search_files` etc.

# %%
# Define a comprehensive system prompt for our agent
system_prompt = """
あなたはAIアシスタントです．
"""

model_id = (
    "llama3.2:1b"  # You can change this to any model you have pulled with Ollama.
)

# %% [markdown]
# #### Configure the Ollama model
#
# Make sure your Ollama service is running at http://localhost:11434 and your `model_id` is in the list of Ollama models printed above.

# %%
ollama_model = OllamaModel(
    model_id=model_id,
    host="http://localhost:11434",
    params={
        "max_tokens": 4096,  # Adjust based on your model's capabilities
        "temperature": 0.7,  # Lower for more deterministic responses, higher for more creative
        "top_p": 0.9,  # Nucleus sampling parameter
        "stream": True,  # Enable streaming responses
    },
)

# Create the agent
local_agent = Agent(
    system_prompt=system_prompt,
    model=ollama_model,
    tools=[file_read, file_write, list_directory],
)

# %% [markdown]
# ## Testing the Agent
#
# Let's test our agent with some example tasks.

# %%
local_agent("現在のディレクトリのファイルを表示してください")

# local_agent("'sample.txt'という名前のファイルを作成し、内容は'これはOllamaエージェントによって作成されたテストファイルです。'にしてください")

# local_agent("'document.txt'ファイルを読み取り、5つの箇条書きで要約してください")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 local_agent("現在のディレクトリのファイルを表示してください")
#       3 # local_agent("'sample.txt'という名前のファイルを作成し、内容は'これはOllamaエージェントによって作成されたテストファイルです。'にしてください")
#       4
#       5 # local_agent("'document.txt'ファイルを読み取り、5つの箇条書きで要約してください")
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/agent/agent.py:335, in Agent.__call__(self, prompt, **kwargs)
#     331 self._start_agent_trace_span(prompt)
#     333 try:
#     334     # Run the event loop and get the result
# --> 335     result = self._run_loop(prompt, kwargs)
#     337     self._end_agent_trace_span(response=result)
#     339     return result
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/agent/agent.py:439, in Agent._run_loop(self, prompt, kwargs, supplementary_callback_handler)
#     436     self.messages.append(new_message)
#     438     # Execute the event loop cycle with retry logic for context limits
# --> 439     return self._execute_event_loop_cycle(invocation_callback_handler, kwargs)
#     441 finally:
#     442     self.conversation_manager.apply_management(self.messages)
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/agent/agent.py:467, in Agent._execute_event_loop_cycle(self, callback_handler, kwargs)
#     463 kwargs.pop("agent", None)  # Remove agent to avoid conflicts
#     465 try:
#     466     # Execute the main event loop cycle
# --> 467     stop_reason, message, metrics, state = event_loop_cycle(
#     468         model=model,
#     469         system_prompt=system_prompt,
#     470         messages=messages,  # will be modified by event_loop_cycle
#     471         tool_config=tool_config,
#     472         callback_handler=callback_handler_override,
#     473         tool_handler=tool_handler,
#     474         tool_execution_handler=tool_execution_handler,
#     475         event_loop_metrics=event_loop_metrics,
#     476         agent=self,
#     477         event_loop_parent_span=self.trace_span,
#     478         **kwargs,
#     479     )
#     481     return AgentResult(stop_reason, message, metrics, state)
#     483 except ContextWindowOverflowException as e:
#     484     # Try reducing the context size and retrying
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/event_loop/event_loop.py:190, in event_loop_cycle(model, system_prompt, messages, tool_config, callback_handler, tool_handler, tool_execution_handler, **kwargs)
#     188         if model_invoke_span:
#     189             tracer.end_span_with_error(model_invoke_span, str(e), e)
# --> 190         raise e
#     192 try:
#     193     # Add message in trace and mark the end of the stream messages trace
#     194     stream_trace.add_message(message)
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/event_loop/event_loop.py:148, in event_loop_cycle(model, system_prompt, messages, tool_config, callback_handler, tool_handler, tool_execution_handler, **kwargs)
#     141 model_invoke_span = tracer.start_model_invoke_span(
#     142     parent_span=cycle_span,
#     143     messages=messages,
#     144     model_id=model_id,
#     145 )
#     147 try:
# --> 148     stop_reason, message, usage, metrics, kwargs["request_state"] = stream_messages(
#     149         model,
#     150         system_prompt,
#     151         messages,
#     152         tool_config,
#     153         callback_handler,
#     154         **kwargs,
#     155     )
#     156     if model_invoke_span:
#     157         tracer.end_model_invoke_span(model_invoke_span, message, usage)
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/event_loop/streaming.py:340, in stream_messages(model, system_prompt, messages, tool_config, callback_handler, **kwargs)
#     337 tool_specs = [tool["toolSpec"] for tool in tool_config.get("tools", [])] or None if tool_config else None
#     339 chunks = model.converse(messages, tool_specs, system_prompt)
# --> 340 return process_stream(chunks, callback_handler, messages, **kwargs)
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/event_loop/streaming.py:290, in process_stream(chunks, callback_handler, messages, **kwargs)
#     286 metrics: Metrics = Metrics(latencyMs=0)
#     288 kwargs.setdefault("request_state", {})
# --> 290 for chunk in chunks:
#     291     # Callback handler call here allows each event to be visible to the caller
#     292     callback_handler(event=chunk)
#     294     if "messageStart" in chunk:
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/types/models/model.py:115, in Model.converse(self, messages, tool_specs, system_prompt)
#     112 response = self.stream(request)
#     114 logger.debug("got response from model")
# --> 115 for event in response:
#     116     yield self.format_chunk(event)
#     118 logger.debug("finished streaming response from model")
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/strands/models/ollama.py:282, in OllamaModel.stream(self, request)
#     279 yield {"chunk_type": "message_start"}
#     280 yield {"chunk_type": "content_start", "data_type": "text"}
# --> 282 for event in response:
#     283     for tool_call in event.message.tool_calls or []:
#     284         yield {"chunk_type": "content_start", "data_type": "tool", "data": tool_call}
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/ollama/_client.py:170, in Client._request.<locals>.inner()
#     168 except httpx.HTTPStatusError as e:
#     169   e.response.read()
# --> 170   raise ResponseError(e.response.text, e.response.status_code) from None
#     172 for line in r.iter_lines():
#     173   part = json.loads(line)
#
# ResponseError: model requires more system memory (2.1 GiB) than is available (1.3 GiB) (status code: 500)

# %%
# Example 2: List files in the current directory
response = local_agent("Show me the files in the current directory")
print(response)

# %%
# Example 3: Create a sample file
response = local_agent(
    "Create a file called 'sample.txt' with the content 'This is a test file created by my Ollama agent.'"
)
print(response)

# %%
# Example 4: create a readme file after reading and understanding multiple files
response = local_agent("Create a readme.md for the current directory")
print(response)

# %% [markdown]
# ## Conclusion
#
# In this notebook, we've created a local personal agent using Stands and Ollama. The agent can perform file operations (read, write, append) and Summarize/Analyze text
#
# This demonstrates the power of running AI models locally with Ollama, combined with the flexibility of strands' tool system. You can extend this agent by adding more tools or using different Ollama models based on your needs.
#
# ### Next Steps (Ideas)
#
# - Try different Ollama models to see how they affect the agent's capabilities
# - Add more complex tools like web search, email sending, or calendar integration
# - Implement memory for the agent to remember past interactions
# - Create a simple UI for interacting with your agent
